# %%
from PIL import Image
import os
import matplotlib.pyplot as plt
from keras.layers import Dense,Flatten,Conv2D
from keras.layers import MaxPooling2D,Dropout, Activation
from keras.models import Sequential
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
datagen = ImageDataGenerator(validation_split=0.3, rescale = 1./255)

# %%
train_it = datagen.flow_from_directory('C:\\Users\\HP\\Desktop\\cnn\\folder\\fruits\\fruits-360_dataset\\fruits-360\\Training', subset='training', class_mode='categorical', batch_size=32)
# Out:
# Found 42388 images belonging to 120 classes.

# %%
val_set = datagen.flow_from_directory('C:\\Users\\HP\\Desktop\\cnn\\folder\\fruits\\fruits-360_dataset\\fruits-360\\Training' , subset='validation', class_mode='categorical', batch_size=32)
# Out:
# Found 18110 images belonging to 120 classes.

# %%
model = Sequential()
model.add(Conv2D(filters = 16, kernel_size = 3, input_shape = (256, 256, 3), activation = 'relu', padding = 'same'))
model.add(MaxPooling2D(pool_size = 2))
model.add(Conv2D(filters = 32, kernel_size = 3, activation = 'relu', padding = 'same'))
model.add(MaxPooling2D(pool_size = 2))
model.add(Conv2D(filters = 64, kernel_size = 3, activation = 'relu', padding = 'same'))
model.add(MaxPooling2D(pool_size = 2))
model.add(Conv2D(filters = 80, kernel_size = 3, activation = 'relu', padding = 'same'))
model.add(MaxPooling2D(pool_size = 2))
model.add(Conv2D(filters = 128, kernel_size = 3, activation = 'relu', padding = 'same'))
model.add(MaxPooling2D(pool_size = 2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(150))
model.add(Activation('relu'))
model.add(Dropout(0.4))
model.add(Dense(120, activation = 'softmax'))

# %%
model.compile('rmsprop',loss = 'categorical_crossentropy',metrics = ["accuracy"])

# %%
model.fit_generator(train_it, steps_per_epoch=150, epochs = 10 , validation_data=val_set, validation_steps=30)
# Out:
# Epoch 1/10
# 150/150 [==============================] - 403s 3s/step - loss: 0.2335 - acc: 0.9260 - val_loss: 0.6316 - val_acc: 0.8542
# Epoch 2/10
# 150/150 [==============================] - 390s 3s/step - loss: 0.2428 - acc: 0.9319 - val_loss: 0.7033 - val_acc: 0.8469
# Epoch 3/10
# 150/150 [==============================] - 401s 3s/step - loss: 0.2372 - acc: 0.9308 - val_loss: 0.5278 - val_acc: 0.8925
# Epoch 4/10
# 150/150 [==============================] - 389s 3s/step - loss: 0.1945 - acc: 0.9427 - val_loss: 0.6861 - val_acc: 0.8781
# Epoch 5/10
# 150/150 [==============================] - 410s 3s/step - loss: 0.1967 - acc: 0.9460 - val_loss: 0.8861 - val_acc: 0.8583
# Epoch 6/10
# 150/150 [==============================] - 395s 3s/step - loss: 0.2090 - acc: 0.9450 - val_loss: 0.7712 - val_acc: 0.8625
# Epoch 7/10
# 150/150 [==============================] - 398s 3s/step - loss: 0.1838 - acc: 0.9498 - val_loss: 1.2780 - val_acc: 0.7969
# Epoch 8/10
# ...

# %%
model.save("fruits_model.h5")

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 32)      4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 80)        46160
# ...

# %%
datagent = ImageDataGenerator(rescale = 1./255)

# %%
test_it = datagent.flow_from_directory('C:\\Users\\HP\\Desktop\\cnn\\folder\\fruits\\fruits-360_dataset\\fruits-360\\Test', class_mode='categorical', batch_size=32)
# Out:
# Found 20622 images belonging to 120 classes.

# %%
yhat = model.predict_generator(test_it, steps=24)

# %%
loss, acc = loss = model.evaluate_generator(test_it, steps=24)

# %%
acc
# Out:
# 0.9348958333333334

# %%
test_cases = ['apple braeburn',
'apple crimson snow',
'apple golden 1',
'apple golden 2',
'apple golden 3',
'apple granny smith',
'apple pink lady',
'apple red 1',
'apple red 2',
'apple red 3',
'apple red delicious',
'apple red yellow 1',
'apple red yellow 2',
'apricot',
'avocado',
'avocado ripe',
'banana',
'banana lady finger',
'banana red',
'beetroot',
'blueberry',
'cactus fruit',
'cantaloupe 1',
'cantaloupe 2',
'carambula',
'cauliflower',
'cherry 1',
'cherry 2',
'cherry rainer',
'cherry wax black',
'cherry wax red',
'cherry wax yellow',
'chestnut',
'clementune',
'cocos',
'dates',
'eggplant',
'ginger root',
'granadilla',
'grape blue',
'grape pink',
'grape white',
'grape white 2',
'grape white 3',
'grape white 4',
'grapefruit pink',
'grapefruit white',
'guava',
'hazelnut',
'huckleberry',
'kaki',
'kiwi',
'kohlrabi',
'kumquats',
'lemon',
'lemon meyer',
'limes',
'lychee',
'mandarine',
'mango',
'mango red',
'mangostan',
'maracuja',
'melon piel de sapo',
'mulberry',
'nectarine',
'nectarine flat',
'nut forest',
'nut pecan',
'onion red',
'onion red peeled',
'onion white',
'orange',
'papaya',
'passion fruit',
'peach',
'peach 2',
'peach flat',
'pear',
'pear abate',
'pear forelle',
'pear kaiser',
'pear monster',
'pear red',
'pear williams',
'pepino',
'pepper green',
'pepper red',
'pepper yellow',
'physalis',
'physalis with husk',
'pineapple',
'pineapple mini',
'pitahaya red',
'plum',
'plum 2',
'plum 3',
'pomegranate',
'pomelo sweetie',
'potato red',
'potato red washed',
'potato sweet',
'potato white',
'quince',
'rambutan',
'raspberry',
'redcurrent',
'salak',
'strawberry',
'strawberry wedge',
'tamarillo',
'tangelo',
'tomato 1',
'tomato 2',
'tomato 3',
'tomato 4',
'tomato cherry red',
'tomato maroon',
'tomato yellow',
'walnut']


print(len(test_cases))
print(y_test.shape)
# Out:
# 120
# (32, 120)

# %%
x_test, y_test = test_it.next()

# %%
y_pred = model.predict(x_test)

# %%
fig = plt.figure(figsize=(16, 9))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=25, replace=False)):
    ax = fig.add_subplot(5, 5, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_pred[idx])
    true_idx = np.argmax(y_test[idx])
    #print(true_idx)
    #print(pred_idx)
    ax.set_title("{} ({})".format(test_cases[pred_idx], test_cases[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))

# %%
score = model.evaluate(x_test, y_test, verbose=0)

# %%
score[0]
# Out:
# 0.1493557095527649

# %%
score[1]
# Out:
# 0.96875
